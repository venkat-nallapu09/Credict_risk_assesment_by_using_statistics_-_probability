# %% [markdown]
# <a href="https://colab.research.google.com/github/venkat-nallapu09/Credict_risk_assesment_by_using_statistics_-_probability/blob/main/Credict_risk_assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Building a Probability-Based Credit Risk Model for German Credit Dataset**

# %% [markdown]
# # **Step 1: Data Preparation**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Load numerical dataset (24 features + target)
data = np.loadtxt('german.data-numeric')
X = data[:, :-1]  # Features
y = np.where(data[:, -1] == 1, 0, 1)  # Convert target: 1=Good(0), 2=Bad(1)

# Split data (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Standardize numerical features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **Step 2: Model Training (Logistic Regression)**

# %%
feature_importance = pd.Series(model.coef_[0], index=range(1,25))
feature_importance.abs().sort_values(ascending=False)
# Out:
# 1     0.680828
# 3     0.443690
# 10    0.329386
# 16    0.316904
# 17    0.314009
# 21    0.294645
# 15    0.285113
# 2     0.272552
# 11    0.207359
# 6     0.205582
# 4     0.202561
# 5     0.189475
# 18    0.186989
# 9     0.168156
# 22    0.148045
# 20    0.136627
# 23    0.127070
# 14    0.126210
# 12    0.117030
# 24    0.111863
# 19    0.103253
# 7     0.095709
# 8     0.032441
# 13    0.027784
# dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# Train model with class weighting
model = LogisticRegression(
    solver='liblinear',
    class_weight='balanced',  # Adjusts for class imbalance
    random_state=42
)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42, solver='liblinear')

# %% [markdown]
# # **Step 3: Cost-Optimal Threshold Calculation**

# %%
from sklearn.metrics import confusion_matrix

# Get predicted probabilities for training data
train_probs = model.predict_proba(X_train)[:, 1]  # P(bad)

# Define cost function
def calculate_cost(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return fp * 1 + fn * 5  # Cost matrix weights

# Find optimal threshold
thresholds = np.linspace(0, 1, 101)
costs = []

for thresh in thresholds:
    preds = (train_probs >= thresh).astype(int)
    costs.append(calculate_cost(y_train, preds))

optimal_threshold = thresholds[np.argmin(costs)]
print(f"Optimal threshold: {optimal_threshold:.2f}")  # Typically ~0.3-0.4
# Out:
# Optimal threshold: 0.39

# %% [markdown]
# # **Step 4: Model Evaluation**

# %%
# Test set predictions
test_probs = model.predict_proba(X_test)[:, 1]
test_preds = (test_probs >= optimal_threshold).astype(int)

# Calculate test cost
test_cost = calculate_cost(y_test, test_preds)
print(f"Test set cost: {test_cost}")

# Key metrics
tn, fp, fn, tp = confusion_matrix(y_test, test_preds).ravel()
print(f"""
Confusion Matrix:
| {tp:4d} | {fp:4d} |  (Actual Bad)
| {fn:4d} | {tn:4d} |  (Actual Good)
""")
print(f"False Negative Rate: {fn/(fn+tp):.2%}")
print(f"False Positive Rate: {fp/(fp+tn):.2%}")
# Out:
# Test set cost: 149
#
# Confusion Matrix:
# |   76 |   74 |  (Actual Bad)
# |   15 |  135 |  (Actual Good)
#
# False Negative Rate: 16.48%
# False Positive Rate: 35.41%

# %% [markdown]
# # **Step 5: Risk Tiers Based on Probabilities**

# %%
# Create risk categories
def risk_tier(prob):
    if prob < 0.2:
        return "Low"
    elif prob < 0.5:
        return "Medium"
    else:
        return "High"

# Apply to test cases
risk_tiers = [risk_tier(p) for p in test_probs]

# %%
for index, tier in enumerate(risk_tiers):
    print(f"Index: {index}, Risk Tier: {tier}")
# Out:
# Index: 0, Risk Tier: High
# Index: 1, Risk Tier: High
# Index: 2, Risk Tier: High
# Index: 3, Risk Tier: Medium
# Index: 4, Risk Tier: Low
# Index: 5, Risk Tier: High
# Index: 6, Risk Tier: Low
# Index: 7, Risk Tier: Medium
# Index: 8, Risk Tier: Low
# Index: 9, Risk Tier: Low
# Index: 10, Risk Tier: Medium
# Index: 11, Risk Tier: High
# Index: 12, Risk Tier: Medium
# Index: 13, Risk Tier: High
# Index: 14, Risk Tier: High
# Index: 15, Risk Tier: High
# Index: 16, Risk Tier: Low
# Index: 17, Risk Tier: Low
# Index: 18, Risk Tier: High
# Index: 19, Risk Tier: High
# Index: 20, Risk Tier: Low
# Index: 21, Risk Tier: High
# Index: 22, Risk Tier: Low
# Index: 23, Risk Tier: Low
# Index: 24, Risk Tier: Low
# Index: 25, Risk Tier: High
# Index: 26, Risk Tier: High
# Index: 27, Risk Tier: High
# Index: 28, Risk Tier: Low
# Index: 29, Risk Tier: Medium
# Index: 30, Risk Tier: Medium
# Index: 31, Risk Tier: Medium
# Index: 32, Risk Tier: Medium
# Index: 33, Risk Tier: Medium
# Index: 34, Risk Tier: Medium
# Index: 35, Risk Tier: Medium
# Index: 36, Risk Tier: High
# Index: 37, Risk Tier: Medium
# Index: 38, Risk Tier: Low
# Index: 39, Risk Tier: High
# Index: 40, Risk Tier: Medium
# Index: 41, Risk Tier: Low
# Index: 42, Risk Tier: High
# Index: 43, Risk Tier: Low
# Index: 44, Risk Tier: Medium
# Index: 45, Risk Tier: Medium
# Index: 46, Risk Tier: High
# Index: 47, Risk Tier: Medium
# Index: 48, Risk Tier: Medium
# Index: 49, Risk Tier: Medium
# Index: 50, Risk Tier: High
# Index: 51, Risk Tier: Low
# Index: 52, Risk Tier: High
# Index: 53, Risk Tier: High
# Index: 54, Risk Tier: Low
# Index: 55, Risk Tier: Medium
# Index: 56, Risk Tier: High
# Index: 57, Risk Tier: High
# Index: 58, Risk Tier: High
# Index: 59, Risk Tier: Medium
# Index: 60, Risk Tier: Medium
# Index: 61, Risk Tier: High
# Index: 62, Risk Tier: High
# Index: 63, Risk Tier: Low
# Index: 64, Risk Tier: Medium
# Index: 65, Risk Tier: High
# Index: 66, Risk Tier: Low
# Index: 67, Risk Tier: High
# Index: 68, Risk Tier: Medium
# Index: 69, Risk Tier: Medium
# Index: 70, Risk Tier: High
# Index: 71, Risk Tier: Medium
# Index: 72, Risk Tier: Medium
# Index: 73, Risk Tier: High
# Index: 74, Risk Tier: Medium
# Index: 75, Risk Tier: High
# Index: 76, Risk Tier: High
# Index: 77, Risk Tier: Medium
# Index: 78, Risk Tier: Medium
# Index: 79, Risk Tier: High
# Index: 80, Risk Tier: Medium
# Index: 81, Risk Tier: Medium
# Index: 82, Risk Tier: Medium
# Index: 83, Risk Tier: High
# Index: 84, Risk Tier: Low
# Index: 85, Risk Tier: High
# Index: 86, Risk Tier: High
# Index: 87, Risk Tier: High
# Index: 88, Risk Tier: Medium
# Index: 89, Risk Tier: Medium
# Index: 90, Risk Tier: Medium
# Index: 91, Risk Tier: Low
# Index: 92, Risk Tier: High
# Index: 93, Risk Tier: High
# Index: 94, Risk Tier: Low
# Index: 95, Risk Tier: Low
# Index: 96, Risk Tier: Medium
# Index: 97, Risk Tier: High
# Index: 98, Risk Tier: High
# Index: 99, Risk Tier: High
# Index: 100, Risk Tier: Low
# Index: 101, Risk Tier: Medium
# Index: 102, Risk Tier: Medium
# Index: 103, Risk Tier: Low
# Index: 104, Risk Tier: Medium
# Index: 105, Risk Tier: Medium
# Index: 106, Risk Tier: Medium
# Index: 107, Risk Tier: High
# Index: 108, Risk Tier: Medium
# Index: 109, Risk Tier: High
# Index: 110, Risk Tier: High
# Index: 111, Risk Tier: Medium
# Index: 112, Risk Tier: High
# Index: 113, Risk Tier: Low
# Index: 114, Risk Tier: Medium
# Index: 115, Risk Tier: High
# Index: 116, Risk Tier: High
# Index: 117, Risk Tier: Medium
# Index: 118, Risk Tier: Medium
# Index: 119, Risk Tier: Medium
# Index: 120, Risk Tier: Medium
# Index: 121, Risk Tier: Medium
# Index: 122, Risk Tier: Medium
# Index: 123, Risk Tier: High
# Index: 124, Risk Tier: High
# Index: 125, Risk Tier: Medium
# Index: 126, Risk Tier: High
# Index: 127, Risk Tier: Low
# Index: 128, Risk Tier: Low
# Index: 129, Risk Tier: Low
# Index: 130, Risk Tier: Medium
# Index: 131, Risk Tier: Medium
# Index: 132, Risk Tier: Medium
# Index: 133, Risk Tier: Low
# Index: 134, Risk Tier: High
# Index: 135, Risk Tier: Medium
# Index: 136, Risk Tier: High
# Index: 137, Risk Tier: Low
# Index: 138, Risk Tier: High
# Index: 139, Risk Tier: High
# Index: 140, Risk Tier: High
# Index: 141, Risk Tier: Medium
# Index: 142, Risk Tier: High
# Index: 143, Risk Tier: Low
# Index: 144, Risk Tier: Medium
# Index: 145, Risk Tier: High
# Index: 146, Risk Tier: Medium
# Index: 147, Risk Tier: Medium
# Index: 148, Risk Tier: High
# Index: 149, Risk Tier: High
# Index: 150, Risk Tier: Low
# Index: 151, Risk Tier: High
# Index: 152, Risk Tier: Medium
# Index: 153, Risk Tier: High
# Index: 154, Risk Tier: Low
# Index: 155, Risk Tier: High
# Index: 156, Risk Tier: High
# Index: 157, Risk Tier: Low
# Index: 158, Risk Tier: Medium
# Index: 159, Risk Tier: High
# Index: 160, Risk Tier: High
# Index: 161, Risk Tier: Low
# Index: 162, Risk Tier: High
# Index: 163, Risk Tier: High
# Index: 164, Risk Tier: Medium
# Index: 165, Risk Tier: High
# Index: 166, Risk Tier: Low
# Index: 167, Risk Tier: High
# Index: 168, Risk Tier: Low
# Index: 169, Risk Tier: High
# Index: 170, Risk Tier: Medium
# Index: 171, Risk Tier: Medium
# Index: 172, Risk Tier: High
# Index: 173, Risk Tier: Medium
# Index: 174, Risk Tier: Low
# Index: 175, Risk Tier: Medium
# Index: 176, Risk Tier: Medium
# Index: 177, Risk Tier: Low
# Index: 178, Risk Tier: High
# Index: 179, Risk Tier: High
# Index: 180, Risk Tier: Medium
# Index: 181, Risk Tier: Low
# Index: 182, Risk Tier: Low
# Index: 183, Risk Tier: Low
# Index: 184, Risk Tier: Medium
# Index: 185, Risk Tier: Low
# Index: 186, Risk Tier: High
# Index: 187, Risk Tier: Low
# Index: 188, Risk Tier: Low
# Index: 189, Risk Tier: Low
# Index: 190, Risk Tier: Low
# Index: 191, Risk Tier: High
# Index: 192, Risk Tier: High
# Index: 193, Risk Tier: Medium
# Index: 194, Risk Tier: Low
# Index: 195, Risk Tier: Medium
# Index: 196, Risk Tier: High
# Index: 197, Risk Tier: High
# Index: 198, Risk Tier: Medium
# Index: 199, Risk Tier: Medium
# Index: 200, Risk Tier: High
# Index: 201, Risk Tier: Medium
# Index: 202, Risk Tier: Low
# Index: 203, Risk Tier: High
# Index: 204, Risk Tier: Medium
# Index: 205, Risk Tier: High
# Index: 206, Risk Tier: Low
# Index: 207, Risk Tier: High
# Index: 208, Risk Tier: High
# Index: 209, Risk Tier: Medium
# Index: 210, Risk Tier: Low
# Index: 211, Risk Tier: High
# Index: 212, Risk Tier: High
# Index: 213, Risk Tier: High
# Index: 214, Risk Tier: High
# Index: 215, Risk Tier: Low
# Index: 216, Risk Tier: Low
# Index: 217, Risk Tier: Medium
# Index: 218, Risk Tier: High
# Index: 219, Risk Tier: Medium
# Index: 220, Risk Tier: Low
# Index: 221, Risk Tier: Low
# Index: 222, Risk Tier: Medium
# Index: 223, Risk Tier: Medium
# Index: 224, Risk Tier: High
# Index: 225, Risk Tier: Low
# Index: 226, Risk Tier: Low
# Index: 227, Risk Tier: Medium
# Index: 228, Risk Tier: Low
# Index: 229, Risk Tier: Medium
# Index: 230, Risk Tier: Medium
# Index: 231, Risk Tier: Low
# Index: 232, Risk Tier: High
# Index: 233, Risk Tier: Medium
# Index: 234, Risk Tier: Low
# Index: 235, Risk Tier: High
# Index: 236, Risk Tier: Medium
# Index: 237, Risk Tier: Medium
# Index: 238, Risk Tier: High
# Index: 239, Risk Tier: Medium
# Index: 240, Risk Tier: High
# Index: 241, Risk Tier: Low
# Index: 242, Risk Tier: Medium
# Index: 243, Risk Tier: Medium
# Index: 244, Risk Tier: Medium
# Index: 245, Risk Tier: Medium
# Index: 246, Risk Tier: Low
# Index: 247, Risk Tier: Medium
# Index: 248, Risk Tier: Medium
# Index: 249, Risk Tier: High
# Index: 250, Risk Tier: Medium
# Index: 251, Risk Tier: Medium
# Index: 252, Risk Tier: High
# Index: 253, Risk Tier: Low
# Index: 254, Risk Tier: High
# Index: 255, Risk Tier: High
# Index: 256, Risk Tier: Low
# Index: 257, Risk Tier: Low
# Index: 258, Risk Tier: High
# Index: 259, Risk Tier: High
# Index: 260, Risk Tier: High
# Index: 261, Risk Tier: Medium
# Index: 262, Risk Tier: High
# Index: 263, Risk Tier: Low
# Index: 264, Risk Tier: Medium
# Index: 265, Risk Tier: Medium
# Index: 266, Risk Tier: Low
# Index: 267, Risk Tier: Medium
# Index: 268, Risk Tier: High
# Index: 269, Risk Tier: High
# Index: 270, Risk Tier: Low
# Index: 271, Risk Tier: High
# Index: 272, Risk Tier: Medium
# Index: 273, Risk Tier: Medium
# Index: 274, Risk Tier: Low
# Index: 275, Risk Tier: High
# Index: 276, Risk Tier: Low
# Index: 277, Risk Tier: Medium
# Index: 278, Risk Tier: Low
# Index: 279, Risk Tier: High
# Index: 280, Risk Tier: Medium
# Index: 281, Risk Tier: Medium
# Index: 282, Risk Tier: Medium
# Index: 283, Risk Tier: Low
# Index: 284, Risk Tier: Low
# Index: 285, Risk Tier: Medium
# Index: 286, Risk Tier: High
# Index: 287, Risk Tier: Medium
# Index: 288, Risk Tier: High
# Index: 289, Risk Tier: Medium
# Index: 290, Risk Tier: High
# Index: 291, Risk Tier: Medium
# Index: 292, Risk Tier: High
# Index: 293, Risk Tier: Medium
# Index: 294, Risk Tier: High
# Index: 295, Risk Tier: Medium
# Index: 296, Risk Tier: High
# Index: 297, Risk Tier: Medium
# Index: 298, Risk Tier: High
# Index: 299, Risk Tier: High
